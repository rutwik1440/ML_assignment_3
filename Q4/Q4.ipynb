# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.manifold import TSNE
import tensorflow as tf

# Load MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist["data"], mnist["target"].astype(np.uint8)

# Stratified subset for training if compute is limited
X_train, _, y_train, _ = train_test_split(X, y, train_size=20000, stratify=y, random_state=42)

# Test set remains the same
X_test, y_test = mnist["data"], mnist["target"].astype(np.uint8)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
# Define MLP architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(30, activation="relu", input_shape=(784,)),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
# Train the MLP
model.fit(X_train, y_train, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 563/563 [==============================] - 4s 4ms/step - loss: 4.3021 - accuracy: 0.3857 - val_loss: 1.3398 - val_accuracy: 0.5110
# Epoch 2/20
# 563/563 [==============================] - 2s 3ms/step - loss: 1.1510 - accuracy: 0.6095 - val_loss: 1.0341 - val_accuracy: 0.6770
# Epoch 3/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.8972 - accuracy: 0.7094 - val_loss: 0.8400 - val_accuracy: 0.7445
# Epoch 4/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.7803 - accuracy: 0.7454 - val_loss: 0.7696 - val_accuracy: 0.7570
# Epoch 5/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.7178 - accuracy: 0.7687 - val_loss: 0.6815 - val_accuracy: 0.7900
# Epoch 6/20
# 563/563 [==============================] - 2s 4ms/step - loss: 0.6628 - accuracy: 0.7959 - val_loss: 0.7073 - val_accuracy: 0.7790
# Epoch 7/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.6126 - accuracy: 0.8099 - val_loss: 0.6627 - val_accuracy: 0.8210
# Epoch 8/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5830 - accuracy: 0.8216 - val_loss: 0.6337 - val_accuracy: 0.8240
# Epoch 9/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5343 - accuracy: 0.8484 - val_loss: 0.5739 - val_accuracy: 0.8475
# Epoch 10/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5044 - accuracy: 0.8581 - val_loss: 0.5519 - val_accuracy: 0.8680
# Epoch 11/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4721 - accuracy: 0.8672 - val_loss: 0.5012 - val_accuracy: 0.8710
# Epoch 12/20
# 563/563 [==============================] - 2s 4ms/step - loss: 0.4379 - accuracy: 0.8811 - val_loss: 0.4724 - val_accuracy: 0.8835
# Epoch 13/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4186 - accuracy: 0.8883 - val_loss: 0.4642 - val_accuracy: 0.8975
# Epoch 14/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3926 - accuracy: 0.8960 - val_loss: 0.4316 - val_accuracy: 0.8965
# Epoch 15/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3665 - accuracy: 0.9027 - val_loss: 0.4320 - val_accuracy: 0.8965
# Epoch 16/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3550 - accuracy: 0.9096 - val_loss: 0.4386 - val_accuracy: 0.8920
# Epoch 17/20
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3435 - accuracy: 0.9107 - val_loss: 0.4238 - val_accuracy: 0.9055
# Epoch 18/20
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3282 - accuracy: 0.9171 - val_loss: 0.3859 - val_accuracy: 0.9050
# Epoch 19/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3190 - accuracy: 0.9166 - val_loss: 0.3892 - val_accuracy: 0.9075
# Epoch 20/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3042 - accuracy: 0.9229 - val_loss: 0.3552 - val_accuracy: 0.9110

# %%
# Evaluate the MLP
mlp_pred = np.argmax(model.predict(X_test), axis=1)
mlp_f1 = f1_score(y_test, mlp_pred, average='macro')
mlp_cm = confusion_matrix(y_test, mlp_pred)

# Compare against RF and LR models
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_f1 = f1_score(y_test, rf_pred, average='macro')
rf_cm = confusion_matrix(y_test, rf_pred)

lr_model = LogisticRegression(max_iter=1000, random_state=42)
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)
lr_f1 = f1_score(y_test, lr_pred, average='macro')
lr_cm = confusion_matrix(y_test, lr_pred)
# Out:
# 2188/2188 [==============================] - 4s 2ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Visualize confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(mlp_cm, cmap='Blues', interpolation='nearest')
axes[0].set_title('MLP Confusion Matrix')
for i in range(10):
    for j in range(10):
        axes[0].text(j, i, mlp_cm[i, j], ha='center', va='center', color='white')
axes[1].imshow(rf_cm, cmap='Blues', interpolation='nearest')
axes[1].set_title('RF Confusion Matrix')
for i in range(10):
    for j in range(10):
        axes[1].text(j, i, rf_cm[i, j], ha='center', va='center', color='white')
axes[2].imshow(lr_cm, cmap='Blues', interpolation='nearest')
axes[2].set_title('LR Confusion Matrix')
for i in range(10):
    for j in range(10):
        axes[2].text(j, i, lr_cm[i, j], ha='center', va='center', color='white')
plt.show()

# %%
print("MLP F1-score:", mlp_f1)
print("RF F1-score:", rf_f1)
print("LR F1-score:", lr_f1)
# Out:
# MLP F1-score: 0.910880751360985
# RF F1-score: 0.9693553574689959
# LR F1-score: 0.8949246562598242

# %%
most_confused_pairs_mlp = []
for i in range(10):  # Assuming 10 classes
    col = mlp_cm[:, i]  # Get the ith column
    max_value = max(col)
    max_index = np.where(col == max_value)[0][0]  # Index of maximum value
    frequent_elements = np.where(col > 150)[0]
    pairs = [(max_index, elem) for elem in frequent_elements if max_index != elem]  # Filter out pairs where both elements are equal
    most_confused_pairs_mlp.extend(pairs)


for pair in most_confused_pairs_mlp:
    print("Most confused pair in MLP:", pair)

most_confused_pairs_rf = []
for i in range(10):  # Assuming 10 classes
    col = rf_cm[:, i]  # Get the ith column
    max_value = max(col)
    max_index = np.where(col == max_value)[0][0]  # Index of maximum value
    frequent_elements = np.where(col > 150)[0]
    pairs = [(max_index, elem) for elem in frequent_elements if max_index != elem]  # Filter out pairs where both elements are equal
    most_confused_pairs_rf.extend(pairs)


for pair in most_confused_pairs_rf:
    print("Most confused pair in RF:", pair)

most_confused_pairs_lr = []
for i in range(10):  # Assuming 10 classes
    col = lr_cm[:, i]  # Get the ith column
    max_value = max(col)
    max_index = np.where(col == max_value)[0][0]  # Index of maximum value
    frequent_elements = np.where(col > 150)[0]
    pairs = [(max_index, elem) for elem in frequent_elements if max_index != elem]  # Filter out pairs where both elements are equal
    most_confused_pairs_lr.extend(pairs)


for pair in most_confused_pairs_lr:
    print("Most confused pair in LR:", pair)
# Out:
# Most confused pair in MLP: (0, 5)
# Most confused pair in MLP: (2, 3)
# Most confused pair in MLP: (3, 2)
# Most confused pair in MLP: (3, 5)
# Most confused pair in MLP: (5, 3)
# Most confused pair in MLP: (5, 8)
# Most confused pair in MLP: (6, 0)
# Most confused pair in MLP: (8, 2)
# Most confused pair in MLP: (8, 3)
# Most confused pair in MLP: (8, 5)
# Most confused pair in MLP: (9, 4)
# Most confused pair in MLP: (9, 5)
# Most confused pair in LR: (2, 3)
# Most confused pair in LR: (2, 8)
# Most confused pair in LR: (3, 2)
# Most confused pair in LR: (3, 5)
# Most confused pair in LR: (3, 8)
# Most confused pair in LR: (4, 9)
# Most confused pair in LR: (5, 3)
# Most confused pair in LR: (5, 8)
# Most confused pair in LR: (7, 9)
# Most confused pair in LR: (8, 2)
# Most confused pair in LR: (8, 3)
# Most confused pair in LR: (8, 5)
# Most confused pair in LR: (9, 4)
# Most confused pair in LR: (9, 7)

# %%
# # t-SNE visualization
# tsne = TSNE(n_components=2, random_state=42)
# X_train_tsne = tsne.fit_transform(X_train)
# X_test_tsne = tsne.fit_transform(X_test)

# plt.figure(figsize=(12, 6))
# plt.subplot(121)
# for i in range(10):
#     plt.scatter(X_train_tsne[y_train == i, 0], X_train_tsne[y_train == i, 1], label=str(i))
# plt.title('t-SNE for MLP trained model')
# plt.legend()

# plt.subplot(122)
# for i in range(10):
#     plt.scatter(X_test_tsne[y_test == i, 0], X_test_tsne[y_test == i, 1], label=str(i))
# plt.title('t-SNE for untrained model')
# plt.legend()
# plt.show()

# %%
# # Apply MLP on Fashion-MNIST dataset
# fashion_mnist = fetch_openml('Fashion-MNIST', version=1)
# X_fashion1 = fashion_mnist["data"]
# y_fashion1 = fashion_mnist["target"].astype(np.uint8)

# X_fashion, _, y_fashion, _ = train_test_split(X_fashion1, y_fashion1, train_size=20000, stratify=y, random_state=42)

# # Predict on Fashion-MNIST
# fashion_pred = np.argmax(model.predict(X_fashion), axis=1)
# fashion_f1 = f1_score(y_fashion, fashion_pred, average='macro')

# print("F1-score on Fashion-MNIST using MLP:", fashion_f1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# 625/625 [==============================] - 1s 2ms/step
# F1-score on Fashion-MNIST using MLP: 0.04895575247465637

# %%
# # Visualize t-SNE for Fashion-MNIST
# X_fashion_tsne = tsne.fit_transform(X_fashion)

# plt.figure(figsize=(6, 6))
# for i in range(10):
#     plt.scatter(X_fashion_tsne[y_fashion == i, 0], X_fashion_tsne[y_fashion == i, 1], label=str(i))
# plt.title('t-SNE for Fashion-MNIST using MLP trained model')
# plt.legend()
# plt.show()

# %%
corrected code from here

# %%
# Get output from the layer containing 20 neurons
layer_20_model = tf.keras.models.Model(inputs=model.input, outputs=model.layers[1].output)
layer_20_output_train = layer_20_model.predict(X_train)
layer_20_output_test = layer_20_model.predict(X_test)

# t-SNE visualization for the second layer output
tsne = TSNE(n_components=2, random_state=42)
layer_20_output_train_tsne = tsne.fit_transform(layer_20_output_train)
layer_20_output_test_tsne = tsne.fit_transform(layer_20_output_test)

plt.figure(figsize=(12, 6))
plt.subplot(121)
for i in range(10):
    plt.scatter(layer_20_output_train_tsne[y_train == i, 0], layer_20_output_train_tsne[y_train == i, 1], label=str(i))
plt.title('t-SNE for MLP trained model (Second Layer Output)')
plt.legend()

plt.subplot(122)
for i in range(10):
    plt.scatter(layer_20_output_test_tsne[y_test == i, 0], layer_20_output_test_tsne[y_test == i, 1], label=str(i))
plt.title('t-SNE for untrained model (Second Layer Output)')
plt.legend()
plt.show()
# Out:
# 625/625 [==============================] - 1s 1ms/step
# 2188/2188 [==============================] - 3s 1ms/step

# %%
# Apply MLP on Fashion-MNIST dataset
fashion_mnist = fetch_openml('Fashion-MNIST', version=1)
X_fashion = fashion_mnist["data"]
y_fashion = fashion_mnist["target"].astype(np.uint8)

# Predict on Fashion-MNIST
fashion_pred = np.argmax(model.predict(X_fashion), axis=1)
fashion_f1 = f1_score(y_fashion, fashion_pred, average='macro')

print("F1-score on Fashion-MNIST using MLP:", fashion_f1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# 2188/2188 [==============================] - 4s 2ms/step
# F1-score on Fashion-MNIST using MLP: 0.04243302315779971

# %%
# Get output from the layer containing 20 neurons for Fashion-MNIST
layer_20_output_fashion = layer_20_model.predict(X_fashion)
# Out:
# 2188/2188 [==============================] - 3s 1ms/step

# %%
# t-SNE visualization for Fashion-MNIST
layer_20_output_fashion_tsne = tsne.fit_transform(layer_20_output_fashion)

plt.figure(figsize=(6, 6))
for i in range(10):
    plt.scatter(layer_20_output_fashion_tsne[y_fashion == i, 0], layer_20_output_fashion_tsne[y_fashion == i, 1], label=str(i))
plt.title('t-SNE for Fashion-MNIST using MLP trained model (Second Layer Output)')
plt.legend()
plt.show()
